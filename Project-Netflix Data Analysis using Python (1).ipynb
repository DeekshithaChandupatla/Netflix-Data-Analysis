# %% [markdown]
# ## Netflix Dataset

# %% [markdown]
# ### Data Analysis Using Python

# %% [markdown]
# ![netflix.logo_.jpg](attachment:netflix.logo_.jpg)

# %% [markdown]
# This Netflix Dataset has information about the TV Shows and Movies available on Netflix(2008-2021).

# %%
import pandas as pd
import numpy as np                 #Importing the required libraries for analysis and visualizatio
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Importing the dataset
data = pd.read_csv(r"C:\Users\deeks\Desktop\Notes\DataSets\Netflix Dataset.csv")                     # to import pandas library

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### Getting some basic information about the dataset and understanding the data

# %% [markdown]
# ### 1. head()

# %%
data.head()                                     # to show top-5 records of the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ### 2. tail()

# %%
data.tail()                                      # to show bottom-5 records of dataset
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# ### 3. shape

# %%
data.shape                                      # to show the No. of Rows and Columns
# Out:
# (7789, 11)

# %% [markdown]
# ### 4. size

# %%
data.size                                      # to show No. of total values(elements) in the dataset
# Out:
# 85679

# %% [markdown]
# ### 5. columns

# %%
data.columns                                   # to show each Column Name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### 6. dtypes

# %%
data.dtypes                                    # to show the data-type of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### 7. info()

# %%
data.info()                                   # To show indexes, columns, data-types of each column, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ----

# %% [markdown]
# ### Task.1. check whether there are any duplicates in the dataset ? If yes, then remove the duplicate records.

# %% [markdown]
# ### duplicate()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]                                         # To check row wise and detect the Duplicate rows
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)                                # To Remove the Duplicate rows permanently

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ----

# %% [markdown]
# ### Task.2. check whether there are any null values in the data

# %% [markdown]
# ### isnull()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.isnull()                                               # To show where Null value is present
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()                                               # To show the count of Null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
round(data.isnull().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Director        31.0
# Cast             9.0
# Country          7.0
# Show_Id          0.0
# Category         0.0
# Title            0.0
# Release_Date     0.0
# Rating           0.0
# Duration         0.0
# Type             0.0
# Description      0.0
# dtype: float64

# %% [markdown]
# If the missing values percentage is more than 10% then we have to treat the missing values other wise we can drop the missing values.Here, Director column has about 31% missing values so we need treat it and the remaining we can drop.

# %% [markdown]
# ### Treating Missing Values/Null Values

# %%
data.fillna({'Director':'Unavailable'},inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
data.shape
# Out:
# (6643, 11)

# %% [markdown]
# ----

# %% [markdown]
# ### Top 5 countries with highest Tv show and movie releases

# %%
data['Country'].value_counts().head(5)
# Out:
# United States     2242
# India              894
# United Kingdom     331
# Japan              220
# South Korea        180
# Name: Country, dtype: int64

# %% [markdown]
# ### graphical representation of count of tv shows and movies among countries

# %%
data['Country'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ----

# %% [markdown]
# ### The year that has highest number of TV Shows & Movie releases

# %% [markdown]
# ### dtypes

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])    #to convert object to date(pd.to_datetime)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%        Unavailable
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# ### dt.year.value_counts()

# %%
year_count=data['Date_N'].dt.year.value_counts()           # It counts the occurrence of all individual Years in Date column.

# %%
year_count
# Out:
# 2019    1848
# 2020    1748
# 2018    1431
# 2017    1022
# 2016     371
# 2021      97
# 2015      74
# 2014      21
# 2011      13
# 2013      11
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: Date_N, dtype: int64

# %% [markdown]
# ### Bar Graph of year and no of releases

# %%
year_count.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ----

# %% [markdown]
# ### No of  Movies & TV Shows in the dataset

# %% [markdown]
# ### groupby()

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%        Unavailable
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category').Category.count()                 # To group all unique items of a column and show their count
# Out:
# Category
# Movie      4761
# TV Show    1882
# Name: Category, dtype: int64

# %% [markdown]
# ### value_counts()

# %%
data['Category'].value_counts()       # another method to get the count of unique items in a column
# Out:
# Movie      4761
# TV Show    1882
# Name: Category, dtype: int64

# %% [markdown]
# ### countplot()

# %%
sns.countplot(data['Category'])        # To show the count of all unique values of any column in the form of bar graph
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ----

# %% [markdown]
# ### Movies that were released in year 2021.

# %%
data['Year'] = data['Date_N'].dt.year                          # to create new Year column ; it will consider only year

# %%
data
# Out:
#      Show_Id Category                  Title           Director  \
# 0         s1  TV Show                     3%        Unavailable
# 1         s2    Movie                  07:19  Jorge Michel Grau
# 2         s3    Movie                  23:59       Gilbert Chan
# 3         s4    Movie                      9        Shane Acker
# 4         s5    Movie                     21     Robert Luketic
# ...      ...      ...                    ...                ...
# 7782   s7781    Movie                    Zoo       Shlok Sharma
# 7783   s7782    Movie                   Zoom       Peter Hewitt
# 7784   s7783    Movie                   Zozo        Josef Fares
# 7785   s7784    Movie                 Zubaan        Mozez Singh
# 7787   s7786  TV Show  Zumbo's Just Desserts        Unavailable
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %% [markdown]
# ### Filtering

# %%
data[ (data['Category'] == 'Movie') & (data['Year']==2008) ]
# Out:
#      Show_Id Category                 Title              Director  \
# 7115   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
#
#          Release_Date Rating Duration                                   Type  \
# 7115  January 1, 2008  TV-MA   81 min  Dramas, Independent Movies, Thrillers
#
#                                             Description     Date_N  Year
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008

# %% [markdown]
# ----

# %% [markdown]
# ### Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix.

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Date_N',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ### value_counts()

# %%
data[data['Director'] !="Unavailable"]['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### records where category is movies and Type is comedies released from Unites States

# %% [markdown]
# #### Filtering

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies') & (data['Country']=='United States')]
# Out:
#      Show_Id Category                                              Title  \
# 33       s34    Movie                                       #realityhigh
# 72       s73    Movie                                           17 Again
# 84       s85    Movie                                          21 & Over
# 174     s175    Movie                        A Futile and Stupid Gesture
# 240     s241    Movie                                   A Thousand Words
# ...      ...      ...                                                ...
# 7321   s7320    Movie  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend
# 7341   s7340    Movie                               Undercover Brother 2
# 7590   s7589    Movie                                  Where's the Money
# 7634   s7633    Movie                                       Wine Country
# 7664   s7663    Movie                                            Work It
#
#                     Director  \
# 33          Fernando Lebrija
# ...

# %% [markdown]
# ----

# %% [markdown]
# ### In how many movies/shows, Tom Cruise was cast.

# %% [markdown]
# ### filtering

# %%
data[data['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data_new = data.copy()

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# ----

# %% [markdown]
# ### Different Ratings defined by Netflix

# %% [markdown]
# ### No of unique Ratings

# %%
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# ### Unique Ratings of Netflix

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'TV-G', 'TV-Y', 'NR',
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data['Rating'].value_counts()
# Out:
# TV-MA       2450
# TV-14       1636
# R            655
# TV-PG        627
# PG-13        375
# PG           238
# TV-Y7        208
# TV-Y         192
# TV-G         146
# NR            66
# G             38
# UR             5
# TV-Y7-FV       4
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# TV-MA is the most common rating which was given to the most of the releases.

# %% [markdown]
# #### Movies that got the 'TV-14' rating, in Canada

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14') & (data['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %% [markdown]
# #### Q.9.2.TV Show got the 'R' rating, after year 2018

# %%
data[(data['Category'] == 'TV Show') & (data["Rating"] == 'R') & (data['Year'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ----

# %% [markdown]
# ### Country that has the Highest No. of TV Shows.

# %%
data_tvshow = data[data['Category'] == 'TV Show']

# %%
data_tvshow["Country"].value_counts().head()
# Out:
# United States     575
# United Kingdom    168
# Japan             153
# South Korea       145
# Taiwan             68
# Name: Country, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    575
# Name: Country, dtype: int64

# %% [markdown]
# ### Country with highest Movie Releases

# %%
data[data["Category"]== "Movie"]["Country"].value_counts().head()
# Out:
# United States     1667
# India              837
# United Kingdom     163
# Canada             106
# Egypt               88
# Name: Country, dtype: int64

# %% [markdown]
# ### Movies/Tv Series that released first

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                            Title  \
# 7115   s7114    Movie             To and From New York
# 3248   s3249    Movie          Just Another Love Story
# 5766   s5766    Movie                         Splatter
# 3840   s3841    Movie      Mad Ron's Prevues from Hell
# 3221   s3222    Movie           Joseph: King of Dreams
# ...      ...      ...                              ...
# 1919   s1920    Movie                Eddie Murphy: Raw
# 6398   s6397    Movie  The Girl with the Dragon Tattoo
# 6446   s6445    Movie              The Heartbreak Club
# 5771   s5771    Movie                  Spring Breakers
# 1673   s1674    Movie                      Death of Me
#
#                             Director  \
# 7115            Sorin Dan Mihalcescu
# 3248                    Ole Bornedal
# 5766                       Joe Dante
# 3840                      Jim Monaco
# 3221   Rob LaDuca, Robert C. Ramirez
# ...                              ...
# ...

# %% [markdown]
# # Extracting and Analysing Releases from India

# %% [markdown]
# ### Tv Shows and Movies released from India

# %%
data[data["Country"]=="India"]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %% [markdown]
# ### Titles of all TV Shows that were released in India only.

# %%
data[ (data['Category']=='TV Show') & (data['Country']=='India') ] ['Title']
# Out:
# 86                 21 Sarfarosh: Saragarhi 1897
# 132                                   7 (Seven)
# 340                                Agent Raghav
# 364                                Akbar Birbal
# 534                 Anjaan: Special Crimes Unit
# 698                  Badalte Rishton Ki Dastaan
# 750                               Bard of Blood
# 856                                      Betaal
# 879                                 Bh Se Bhade
# 880                          Bhaag Beanie Bhaag
# 881                              Bhaage Re Mann
# 1316                               Chhota Bheem
# 1412                            Classic Legends
# 1463                            College Romance
# 1622                       Darr Sabko Lagta Hai
# 1691                                Delhi Crime
# 1729              Devlok with Devdutt Pattanaik
# 1736                              Dharmakshetra
# 2005                          Engineering Girls
# 2331                  Gabru: Hip Hop Revolution
# ...

# %%
data[ (data['Category']=='TV Show') & (data['Country']=='India') ] ['Title'].count()
# Out:
# 57

# %% [markdown]
# 57 TV shows were released from India.

# %%
data[ (data['Category']=='Movie') & (data['Country']=='India') ] ['Title'].count()
# Out:
# 837

# %% [markdown]
# 837 Movies were released from india

# %%
data[data["Country"]=="India"]["Category"].value_counts().reset_index().rename({"index":"Category","Category":"Count"},axis=1)
# Out:
#   Category  Count
# 0    Movie    837
# 1  TV Show     57

# %% [markdown]
# ### Directors who belong to India - 894

# %%
data[data['Country'] == 'India']['Director']
# Out:
# 8            Shravan Kumar
# 9             Vikram Bhatt
# 18      Swapnaneel Jayakar
# 20                    Onir
# 21            Vijay Milton
#                ...
# 7766            Aanand Rai
# 7771           Zoya Akhtar
# 7778      Satyajit Bhatkal
# 7782          Shlok Sharma
# 7785           Mozez Singh
# Name: Director, Length: 894, dtype: object

# %%
data[data['Country'] == 'India']['Director'].count()
# Out:
# 894

# %% [markdown]
# ### Ratings given to Indian Releases

# %%
data[data['Country']=='India']['Rating'].value_counts()
# Out:
# TV-14       513
# TV-MA       219
# TV-PG       126
# TV-Y7         9
# TV-G          6
# TV-Y          5
# NR            5
# PG-13         4
# PG            3
# R             2
# TV-Y7-FV      1
# UR            1
# Name: Rating, dtype: int64

# %% [markdown]
# TV-14 is the rating which was given to the most of the releases from India

# %%
data[data['Country']=="India"]['Rating'].nunique()
# Out:
# 12

# %% [markdown]
# ### Movies where Prabhas was Cast

# %%
data[(data["Country"]=="India") & (data["Cast"].str.contains("Prabhas"))]
# Out:
#      Show_Id Category                                        Title  \
# 656     s657    Movie  Baahubali 2: The Conclusion (Hindi Version)
# 660     s661    Movie     Baahubali: The Beginning (Hindi Version)
# 5326   s5326    Movie                                        Saaho
#
#             Director                                               Cast  \
# 656   S.S. Rajamouli  Prabhas, Rana Daggubati, Anushka Shetty, Taman...
# 660   S.S. Rajamouli  Prabhas, Rana Daggubati, Anushka Shetty, Taman...
# 5326         Sujeeth  Prabhas, Shraddha Kapoor, Jackie Shroff, Chunk...
#
#      Country      Release_Date Rating Duration  \
# 656    India    August 7, 2017  TV-MA  165 min
# 660    India    August 7, 2017  TV-14  159 min
# 5326   India  December 8, 2019  TV-14  172 min
#
#                                                   Type  \
# 656   Action & Adventure, Dramas, International Movies
# 660   Action & Adventure, Dramas, International Movies
# ...

# %% [markdown]
# ### Comedy Movies Released from India

# %%
data[(data["Country"]=="India") & (data["Type"].str.contains("Comedy"))]
# Out:
#      Show_Id Category                                              Title  \
# 312     s313    Movie      Aditi Mittal: Things They Wouldn't Let Me Say
# 477     s478    Movie                     Amit Tandon: Family Tandoncies
# 2350   s2351  TV Show                                  Gangs of Hassepur
# 3339   s3340    Movie  Kenny Sebastian: The Most Interesting Person i...
# 3511   s3512  TV Show                                          Ladies Up
# 4079   s4080  TV Show            Midnight Misadventures With Mallika Dua
# 7429   s7428    Movie                                 Vir Das: For India
# 7431   s7430    Movie         Vir Das: Outside In - The Lockdown Special
# 7746   s7745    Movie                        Yours Sincerely, Kanan Gill
#
#                   Director                                               Cast  \
# 312          Fazila Allana                                       Aditi Mittal
# 477            Unavailable                                        Amit Tandon
# ...

# %%
data[(data["Country"]=="India") & (data["Type"].str.contains("Comedy"))].count()
# Out:
# Show_Id         9
# Category        9
# Title           9
# Director        9
# Cast            9
# Country         9
# Release_Date    9
# Rating          9
# Duration        9
# Type            9
# Description     9
# Date_N          9
# Year            9
# dtype: int64

# %%
data[data["Type"].str.contains("Comedy")]["Country"].value_counts()
# Out:
# United States                    238
# United Kingdom                    21
# Mexico                            18
# India                              9
# Brazil                             9
# Argentina                          7
# South Korea                        5
# Germany                            5
# France                             5
# Italy                              4
# Colombia                           3
# Chile                              3
# Australia                          3
# Canada                             2
# United States, United Kingdom      1
# Iceland                            1
# Sweden                             1
# Singapore                          1
# Netherlands                        1
# Japan                              1
# Name: Country, dtype: int64

# %%
data[data["Type"] == "Comedies"]["Country"].value_counts()
# Out:
# United States                            74
# United Kingdom                            9
# United States, United Kingdom             2
# United States, China                      1
# Canada, United States                     1
# United States, Mexico                     1
# United States, United Kingdom, Japan      1
# Mexico, United States                     1
# Australia                                 1
# Canada                                    1
# Canada, United Kingdom, United States     1
# United Kingdom, United States             1
# Germany, United States                    1
# Name: Country, dtype: int64

# %% [markdown]
# ### Year wise releases in India

# %%
data[data["Country"]=="India"]['Year'].value_counts()
# Out:
# 2018    333
# 2019    219
# 2020    183
# 2017    138
# 2021     12
# 2016      9
# Name: Year, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# By-
# Deekshitha chandupatla
